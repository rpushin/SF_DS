# %%
from IPython.display import display, HTML

display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))

import pandas as pd


football = pd.read_csv('data_sf.csv')
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#     display(football.describe(include = ['object', 'float64', 'int64']))

# display((football[football.Aggression ==  football.Aggression.max()].ShotPower.mean()) / (football[football.Aggression ==  football.Aggression.min()].ShotPower.mean()))

small = football[football.Nationality == 'Spain'].Age.value_counts(normalize = 'True')
display((small))
print(type(small))
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>
# 21    0.117735
# 22    0.095380
# 20    0.077496
# 23    0.071535
# 25    0.064083
# 27    0.062593
# 24    0.059613
# 28    0.053651
# 26    0.053651
# 29    0.047690
# 19    0.047690
# 18    0.038748
# 30    0.038748
# 31    0.032787
# 32    0.032787
# 33    0.031297
# 34    0.022355
# 17    0.013413
# 35    0.011923
# 36    0.010432
# 37    0.008942
# 39    0.002981
# 16    0.002981
# 38    0.001490
# Name: Age, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
football = pd.read_csv('data_sf.csv')
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(football.describe(include = ['object', 'float64', 'int64']))
# Out:
#           Unnamed: 0          Name           Age Nationality  \
# count   12897.000000         12897  12897.000000       12897
# unique           NaN         12326           NaN         156
# top              NaN  J. Rodríguez           NaN     England
# freq             NaN             9           NaN        1368
# mean     6605.040862           NaN     24.795379         NaN
# std      3782.545526           NaN      4.872212         NaN
# min         0.000000           NaN     16.000000         NaN
# 25%      3357.000000           NaN     21.000000         NaN
# 50%      6622.000000           NaN     24.000000         NaN
# 75%      9876.000000           NaN     28.000000         NaN
# max     13125.000000           NaN     45.000000         NaN
#
#                     Club         Value           Wage Position      Crossing  \
# count              12897  1.289700e+04   12897.000000    12897  12897.000000
# ...
